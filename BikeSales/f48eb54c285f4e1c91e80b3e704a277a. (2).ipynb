# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\sneha\Downloads\bike_sales_india.csv")
df.head()
# Out:
#             State  Avg Daily Distance (km)          Brand        Model  \
# 0       Karnataka                    68.84  Royal Enfield   Hunter 350
# 1       Rajasthan                    23.80          Bajaj  Dominar 400
# 2  Madhya Pradesh                    27.67            KTM     125 Duke
# 3       Karnataka                    62.85       Kawasaki    Ninja 300
# 4  Madhya Pradesh                    10.62         Yamaha        FZ V3
#
#    Price (INR)  Year of Manufacture  Engine Capacity (cc) Fuel Type  \
# 0       252816                 2021                   672  Electric
# 1       131100                 2020                   769    Hybrid
# 2       201016                 2020                   216    Hybrid
# 3       132482                 2021                   556    Petrol
# 4       231796                 2019                   298    Petrol
#
#    Mileage (km/l) Owner Type  Registration Year Insurance Status Seller Type  \
# ...

# %%
df.columns
# Out:
# Index(['State', 'Avg Daily Distance (km)', 'Brand', 'Model', 'Price (INR)',
#        'Year of Manufacture', 'Engine Capacity (cc)', 'Fuel Type',
#        'Mileage (km/l)', 'Owner Type', 'Registration Year', 'Insurance Status',
#        'Seller Type', 'Resale Price (INR)', 'City Tier'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   State                    10000 non-null  object
#  1   Avg Daily Distance (km)  10000 non-null  float64
#  2   Brand                    10000 non-null  object
#  3   Model                    10000 non-null  object
#  4   Price (INR)              10000 non-null  int64
#  5   Year of Manufacture      10000 non-null  int64
#  6   Engine Capacity (cc)     10000 non-null  int64
#  7   Fuel Type                10000 non-null  object
#  8   Mileage (km/l)           10000 non-null  float64
#  9   Owner Type               10000 non-null  object
#  10  Registration Year        10000 non-null  int64
#  11  Insurance Status         10000 non-null  object
#  12  Seller Type              10000 non-null  object
#  13  Resale Price (INR)       10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Avg Daily Distance (km)    Price (INR)  Year of Manufacture  \
# count             10000.000000   10000.000000         10000.000000
# mean                 42.533128  224328.722400          2019.510500
# std                  21.676985  100753.660447             2.907668
# min                   5.010000   50031.000000          2015.000000
# 25%                  23.907500  137900.250000          2017.000000
# 50%                  42.480000  223878.000000          2019.000000
# 75%                  61.352500  311464.250000          2022.000000
# max                  80.000000  399981.000000          2024.000000
#
#        Engine Capacity (cc)  Mileage (km/l)  Registration Year  \
# count          10000.000000    10000.000000        10000.00000
# mean             552.695300       67.188926         2020.96510
# std              261.176292       20.891728            2.74897
# min              100.000000       25.000000         2015.00000
# ...

# %%
plt.figure(figsize=(25,3))
plt.scatter(df['Avg Daily Distance (km)'],df['Price (INR)'])
plt.xlabel("Avg Daily Distance (km)")
plt.ylabel("Price (INR)")
plt.show()

# %%
def bar_plot(variable):
    var=df[variable]
    varValue=var.value_counts()
    plt.figure(figsize=(12,3))
    plt.bar(varValue.index,varValue)
    plt.xticks(varValue.index,varValue.index.values)
    plt.ylabel("frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
df.columns
# Out:
# Index(['State', 'Avg Daily Distance (km)', 'Brand', 'Model', 'Price (INR)',
#        'Year of Manufacture', 'Engine Capacity (cc)', 'Fuel Type',
#        'Mileage (km/l)', 'Owner Type', 'Registration Year', 'Insurance Status',
#        'Seller Type', 'Resale Price (INR)', 'City Tier'],
#       dtype='object')

# %%
columns_plot=['Avg Daily Distance (km)', 'Price (INR)', 'Engine Capacity (cc)', 'Mileage (km/l)','Resale Price (INR)']
for i in columns_plot:
    bar_plot(i)
# Out:
# Avg Daily Distance (km):
#  Avg Daily Distance (km)
# 55.64    8
# 61.50    7
# 77.57    7
# 57.96    6
# 76.24    6
#         ..
# 68.03    1
# 49.13    1
# 55.55    1
# 20.85    1
# 45.35    1
# Name: count, Length: 5535, dtype: int64
# Price (INR):
#  Price (INR)
# 194359    3
# 332984    3
# 256374    3
# 243231    2
# 120481    2
#          ..
# 378387    1
# 150587    1
# 117741    1
# 156461    1
# 323583    1
# Name: count, Length: 9863, dtype: int64
# Engine Capacity (cc):
#  Engine Capacity (cc)
# 243    21
# 203    21
# 858    21
# 885    20
# 961    20
#        ..
# 323     4
# 827     4
# 198     4
# 555     2
# 112     2
# Name: count, Length: 901, dtype: int64
# Mileage (km/l):
#  Mileage (km/l)
# 92.75    8
# 96.87    7
# 81.54    7
# 82.43    7
# 61.54    7
#         ..
# 62.96    1
# 28.78    1
# 51.15    1
# 94.23    1
# 41.68    1
# Name: count, Length: 5404, dtype: int64
# Resale Price (INR):
#  Resale Price (INR)
# 149934.18    1
# 69058.05     1
# ...

# %%
plt.hist(df['Avg Daily Distance (km)'])
plt.show()

# %%
plt.hist(df['Engine Capacity (cc)'])
plt.show()

# %%
plt.hist(df['Price (INR)'])
plt.show()

# %%
plt.hist(df['Resale Price (INR)'])
plt.show()

# %%
sns.boxplot(y='Avg Daily Distance (km)',data=df)
# Out:
# <Axes: ylabel='Avg Daily Distance (km)'>

# %%
sns.boxplot(y='Engine Capacity (cc)',data=df)
# Out:
# <Axes: ylabel='Engine Capacity (cc)'>

# %%
sns.boxplot(y='Price (INR)',data=df)
# Out:
# <Axes: ylabel='Price (INR)'>

# %%
sns.boxplot(y='Resale Price (INR)',data=df)
# Out:
# <Axes: ylabel='Resale Price (INR)'>

# %%
df.isnull().sum()
# Out:
# State                      0
# Avg Daily Distance (km)    0
# Brand                      0
# Model                      0
# Price (INR)                0
# Year of Manufacture        0
# Engine Capacity (cc)       0
# Fuel Type                  0
# Mileage (km/l)             0
# Owner Type                 0
# Registration Year          0
# Insurance Status           0
# Seller Type                0
# Resale Price (INR)         0
# City Tier                  0
# dtype: int64

# %%
df.columns
# Out:
# Index(['State', 'Avg Daily Distance (km)', 'Brand', 'Model', 'Price (INR)',
#        'Year of Manufacture', 'Engine Capacity (cc)', 'Fuel Type',
#        'Mileage (km/l)', 'Owner Type', 'Registration Year', 'Insurance Status',
#        'Seller Type', 'Resale Price (INR)', 'City Tier'],
#       dtype='object')

# %%
df.drop(labels=[ 'State',  'Brand', 'Model','Year of Manufacture', 'Fuel Type','Owner Type', 'Registration Year', 'Insurance Status','Seller Type', 'City Tier'], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# Avg Daily Distance (km)    0
# Price (INR)                0
# Engine Capacity (cc)       0
# Mileage (km/l)             0
# Resale Price (INR)         0
# dtype: int64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(),annot=True,fmt='.2f')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
